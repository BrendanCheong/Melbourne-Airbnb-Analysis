# %% [markdown]
# # Prices and Accessibility
#
# As seen from the WordCloud Nltk analysis, some of the most common words commonly grouped up together includes the words "walk", "minutes", "tram", "train" and "stations". This suggests that accessibility is measured by _walking distance_ and places where _tram_ and _train station_ services are available.
#
# Thus, my initial hypothesis still holds: **_more accessible Airbnbs are more expensive_**
#
# In order to find out how price relates to accessibility, I must assign points to places where its more accessible in some sort of "accessibility score". Here are some ideas I can implement:
#
# - Attach a positivity score based on the number of attractions available in transit
# - Attach a transport_options score based on the number of transport options available
# - Attach a walking score. The lower the time taken to get to transport, the higher the score **
#
# But first lets clean the data a bit more, by standardising the the word "minute". I want every variation of the that word to be standardised as "minutes".

# %%
import numpy as np
import pandas as pd

df = pd.read_csv("initial_transit_cleaned.csv")
df.head(20)
# Out:
#                                               transit  price  weekly_price  \
# 0   yes the bus 305,309 is exactly two blocks away...     60           NaN
# 1   easy transport options - the tram is right out...     35         200.0
# 2   our apartment is located within walking distan...    159        1253.0
# 3   public transport is super convenient with a ch...     50         250.0
# 4   if you re arriving via the airport tullamarine...     98         540.0
# 5   8-10 minutes walk to local train station, and ...     50         335.0
# 6   numerous buses on victoria parade will take yo...    100           NaN
# 7   monash university, clayton campus is a 10 minu...     98         535.0
# 8   there are two tram lines right outside the apa...     98         800.0
# 9   our apartment is located within walking distan...    190        1743.0
# 10  yes, minutes to trains, trams and buses but mo...    228        1575.0
# 11  the city district of melbourne is thirty minut...     46         320.0
# 12  30 minutes to the city by car and forty minute...     50         300.0
# 13  its a 15 minutes walk to the moorabbin station...     43         300.0
# 14  our apartment is located within walking distan...    138        1183.0
# 15  there are trams in very close vicinity 11 tram...    161           NaN
# 16  walking distance to hampton street, brighton b...    300           NaN
# 17  the area is well serviced with trams, trains a...    140         920.0
# 18  if you dont have a car there is excellent publ...    180        1000.0
# 19  bus at the end of the street. frankston statio...     60         343.0
#
#     monthly_price          host_neighborhood                          street  \
# 0             NaN                        NaN         Bulleen, VIC, Australia
# 1           803.0                  Brunswick  Brunswick East, VIC, Australia
# 2          4452.0                   St Kilda        St Kilda, VIC, Australia
# 3           920.0                  Thornbury       Thornbury, VIC, Australia
# 4             NaN                        NaN         Berwick, VIC, Australia
# 5          1400.0                        NaN       Reservoir, VIC, Australia
# 6             NaN                        NaN  East Melbourne, VIC, Australia
# 7             NaN                        NaN   Oakleigh East, VIC, Australia
# 8             NaN                   Richmond        Richmond, VIC, Australia
# 9          5572.0                   St Kilda        St Kilda, VIC, Australia
# 10         5100.0  Central Business District       Melbourne, VIC, Australia
# 11         1150.0                   Brighton       Melbourne, VIC, Australia
# 12         1000.0                   Brighton       Melbourne, VIC, Australia
# 13         1100.0                   Brighton   Brighton East, VIC, Australia
# 14         4172.0                   St Kilda        Richmond, VIC, Australia
# 15            NaN                        NaN         Fitzroy, VIC, Australia
# 16            NaN                        NaN         Hampton, VIC, Australia
# 17         3000.0                  Thornbury       Thornbury, VIC, Australia
# 18         4000.0               Clifton Hill    Clifton Hill, VIC, Australia
# 19         1260.0                        NaN       Frankston, VIC, Australia
#
#                  neighborhood          city          suburb state language
# 0                Balwyn North    Manningham         Bulleen   VIC       en
# 1                   Brunswick      Moreland  Brunswick East   VIC       en
# 2                    St Kilda  Port Phillip        St Kilda   VIC       en
# 3                   Thornbury       Darebin       Thornbury   VIC       en
# 4                         NaN         Casey         Berwick   VIC       en
# 5                         NaN       Darebin       Reservoir   VIC       en
# 6                         NaN     Melbourne  East Melbourne   VIC       en
# 7                         NaN        Monash   Oakleigh East   VIC       en
# 8                    Richmond         Yarra        Richmond   VIC       en
# 9                    St Kilda  Port Phillip        St Kilda   VIC       en
# 10  Central Business District     Melbourne       Melbourne   VIC       en
# 11                   Brighton       Bayside       Melbourne   VIC       en
# 12                   Brighton       Bayside       Melbourne   VIC       en
# 13                   Brighton       Bayside   Brighton East   VIC       en
# 14                   Richmond         Yarra        Richmond   VIC       en
# 15                    Fitzroy         Yarra         Fitzroy   VIC       en
# 16                   Brighton       Bayside         Hampton   VIC       en
# 17                  Thornbury       Darebin       Thornbury   VIC       en
# 18               Clifton Hill         Yarra    Clifton Hill   VIC       en
# 19                        NaN     Frankston       Frankston   VIC       en

# %%
import re

def clean_text(string_in):
    string_in = re.sub("\\s(?:min|mins|minute)(?=\\s|$)|^(?:min|mins|minute)(?=\\s)", "  minutes  ", str(string_in))  # Replace minute variations spaces
    string_in = re.sub("[\-]", " ", str(string_in))       # get rid of all hyphens 
    string_in = re.sub(" +", " ", str(string_in))         # Turn all multiple spaces with just one space
    string_in = string_in.lower()                         # turn all into lower-case   
    
    return string_in.strip()
df["transit"] = df.transit.apply(clean_text)
df = df[df['transit'].notna()]
df.to_csv("initial_transit_cleaned.csv", index=False)
df.head(20)
# Out:
#                                               transit  price  weekly_price  \
# 0   yes the bus 305,309 is exactly two blocks away...     60           NaN
# 1   easy transport options the tram is right outside.     35         200.0
# 2   our apartment is located within walking distan...    159        1253.0
# 3   public transport is super convenient with a ch...     50         250.0
# 4   if you re arriving via the airport tullamarine...     98         540.0
# 5   8 10 minutes walk to local train station, and ...     50         335.0
# 6   numerous buses on victoria parade will take yo...    100           NaN
# 7   monash university, clayton campus is a 10 minu...     98         535.0
# 8   there are two tram lines right outside the apa...     98         800.0
# 9   our apartment is located within walking distan...    190        1743.0
# 10  yes, minutes to trains, trams and buses but mo...    228        1575.0
# 11  the city district of melbourne is thirty minut...     46         320.0
# 12  30 minutes to the city by car and forty minute...     50         300.0
# 13  its a 15 minutes walk to the moorabbin station...     43         300.0
# 14  our apartment is located within walking distan...    138        1183.0
# 15  there are trams in very close vicinity 11 tram...    161           NaN
# 16  walking distance to hampton street, brighton b...    300           NaN
# 17  the area is well serviced with trams, trains a...    140         920.0
# 18  if you dont have a car there is excellent publ...    180        1000.0
# 19  bus at the end of the street. frankston statio...     60         343.0
#
#     monthly_price          host_neighborhood                          street  \
# 0             NaN                        NaN         Bulleen, VIC, Australia
# 1           803.0                  Brunswick  Brunswick East, VIC, Australia
# 2          4452.0                   St Kilda        St Kilda, VIC, Australia
# 3           920.0                  Thornbury       Thornbury, VIC, Australia
# 4             NaN                        NaN         Berwick, VIC, Australia
# 5          1400.0                        NaN       Reservoir, VIC, Australia
# 6             NaN                        NaN  East Melbourne, VIC, Australia
# 7             NaN                        NaN   Oakleigh East, VIC, Australia
# 8             NaN                   Richmond        Richmond, VIC, Australia
# 9          5572.0                   St Kilda        St Kilda, VIC, Australia
# 10         5100.0  Central Business District       Melbourne, VIC, Australia
# 11         1150.0                   Brighton       Melbourne, VIC, Australia
# 12         1000.0                   Brighton       Melbourne, VIC, Australia
# 13         1100.0                   Brighton   Brighton East, VIC, Australia
# 14         4172.0                   St Kilda        Richmond, VIC, Australia
# 15            NaN                        NaN         Fitzroy, VIC, Australia
# 16            NaN                        NaN         Hampton, VIC, Australia
# 17         3000.0                  Thornbury       Thornbury, VIC, Australia
# 18         4000.0               Clifton Hill    Clifton Hill, VIC, Australia
# 19         1260.0                        NaN       Frankston, VIC, Australia
#
#                  neighborhood          city          suburb state language
# 0                Balwyn North    Manningham         Bulleen   VIC       en
# 1                   Brunswick      Moreland  Brunswick East   VIC       en
# 2                    St Kilda  Port Phillip        St Kilda   VIC       en
# 3                   Thornbury       Darebin       Thornbury   VIC       en
# 4                         NaN         Casey         Berwick   VIC       en
# 5                         NaN       Darebin       Reservoir   VIC       en
# 6                         NaN     Melbourne  East Melbourne   VIC       en
# 7                         NaN        Monash   Oakleigh East   VIC       en
# 8                    Richmond         Yarra        Richmond   VIC       en
# 9                    St Kilda  Port Phillip        St Kilda   VIC       en
# 10  Central Business District     Melbourne       Melbourne   VIC       en
# 11                   Brighton       Bayside       Melbourne   VIC       en
# 12                   Brighton       Bayside       Melbourne   VIC       en
# 13                   Brighton       Bayside   Brighton East   VIC       en
# 14                   Richmond         Yarra        Richmond   VIC       en
# 15                    Fitzroy         Yarra         Fitzroy   VIC       en
# 16                   Brighton       Bayside         Hampton   VIC       en
# 17                  Thornbury       Darebin       Thornbury   VIC       en
# 18               Clifton Hill         Yarra    Clifton Hill   VIC       en
# 19                        NaN     Frankston       Frankston   VIC       en

# %% [markdown]
# # Performing Sentiment Analysis with VADER + custom words
#
# Using nltk's VADER, I will add more custom words to the positive indicators.
#
# First I will apply the lexicon for attractions keywords
# Then apply that for transport keywords
# Lastly, combine the two fields into one

# %% [markdown]
# ### Attractions

# %%
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

Analyzer = SentimentIntensityAnalyzer()
attractions_map = {
    "cbd": 1.0,
    "city": 1.0,
    "supermarket": 1.0,
    "supermarkets": 1.0,
    "shopping": 2.0,
    "cafes": 2.0,
    "cafe": 2.0,
    "beach": 2.0,
    "beaches": 2.0,
    "docklands": 1.0,
    "dockland": 1.0,
    "university": 1.0,
    "restaurant": 2.0,
    "restaurants": 2.0,
    "sports": 1.0,
    "mall": 2.0,
    "market": 2.0,
    "malls": 2.0,
    "groccery": 2.0,
    "grocceries": 2.0,
    "casino": 2.0,
    "parliment": 1.0,
    "town": 2.0,
    "hotel": 1.0
}

transport_map = {
    "tram": 1.0,
    "trams": 1.0,
    "station": 1.0,
    "stations": 1.0,
    "free": 2.0,
    "airport": 2.0,
    "bus": 1.0,
    "buses": 1.0,
    "car": 1.0,
    "cars": 1.0,
    "parking": 1.0,
    "trains": 1.0,
    "train": 1.0,
    "cab": 1.0,
    "cabs": 1.0,
    "taxi": 1.0,
    "taxis": 1.0,
    "uber": 1.0,
    "drive": 1.0,
    "walk": 1.0,
    "bike": 1.0,
    "bikes": 1.0,
    "walking": 1.0,
    "walks": 1.0,
    "ride": 1.0,
    "skybus": 1.0,
    "railway": 1.0,
    "metro": 1.0

}
Analyzer.lexicon.update(attractions_map) # add to lexicon
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\brend\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
all(map(Analyzer.lexicon.pop, attractions_map)) # remove from lexicon
# Out:
# True

# %%
# getting only the positive score
def positive_score(text):
    positive_value = Analyzer.polarity_scores(text)['pos']
    return positive_value

# %%
# %%time

df['attractions_score'] = df['transit'].apply(positive_score)
df.head(20)
# Out:
# Wall time: 4.78 s
#                                               transit  price  weekly_price  \
# 6   numerous buses on victoria parade will take yo...    100           NaN
# 10  yes, minutes to trains, trams and buses but mo...    228        1575.0
# 24  i have a myki available for you. it will have ...     64           NaN
# 30  trams at the door. hire a bike. book the airpo...    140           NaN
# 44  places to walk to .1min walk to lygon st .8min...    161        1030.0
# 49  flinders street station is a few minutes walk ...    220        1400.0
# 53  close and convenient public transport. easy ac...    190         900.0
# 54  tram stop almost at the door, and walking dist...    155         910.0
# 55  the apartment is perfectly located for you to ...     90           NaN
# 57  there is a tram to the city at end of street 1...     84           NaN
# 59  guests have access to three tram lines and the...    226        1575.0
# 64  you never need a car or worry about getting ar...    125         350.0
# 65  yes, trams are just at the end of the street, ...    125         800.0
# 75  trams, trains and buses are all within a block...     75         550.0
# 76  trams, trains and buses are all within a block...     75         550.0
# 79  public transport is very close and very conven...    109           NaN
# 82  parking i sure can be arranged at extra cost. ...    357        2400.0
# 85               exceptionally good. tram, bus, trams    109           NaN
# 88  there is a railway station and tram stop at th...    129         750.0
# 96  there is a tram stop in front of the apartment...    132         895.0
#
#     monthly_price          host_neighborhood                           street  \
# 6             NaN                        NaN   East Melbourne, VIC, Australia
# 10         5100.0  Central Business District        Melbourne, VIC, Australia
# 24            NaN  Central Business District        Melbourne, VIC, Australia
# 30            NaN  Central Business District        Melbourne, VIC, Australia
# 44         3400.0                   Richmond          Carlton, VIC, Australia
# 49         3862.0  Central Business District        Melbourne, VIC, Australia
# 53         2500.0                        NaN        Parkville, VIC, Australia
# 54         3300.0            North Melbourne  North Melbourne, VIC, Australia
# 55            NaN                  Parkville        Parkville, VIC, Australia
# 57            NaN             East Melbourne   East Melbourne, VIC, Australia
# 59            NaN             East Melbourne        Melbourne, VIC, Australia
# 64         1250.0            North Melbourne  North Melbourne, VIC, Australia
# 65         2700.0  Central Business District        Melbourne, VIC, Australia
# 75         1800.0  Central Business District        Melbourne, VIC, Australia
# 76         1900.0  Central Business District        Melbourne, VIC, Australia
# 79         3185.0             East Melbourne   East Melbourne, VIC, Australia
# 82         9000.0            South Melbourne        Southbank, VIC, Australia
# 85            NaN             East Melbourne   East Melbourne, VIC, Australia
# 88         2900.0  Central Business District        Melbourne, VIC, Australia
# 96         3763.0  Central Business District        Melbourne, VIC, Australia
#
#                  neighborhood       city           suburb state language  \
# 6                         NaN  Melbourne   East Melbourne   VIC       en
# 10  Central Business District  Melbourne        Melbourne   VIC       en
# 24  Central Business District  Melbourne        Melbourne   VIC       en
# 30  Central Business District  Melbourne        Melbourne   VIC       en
# 44                    Carlton  Melbourne          Carlton   VIC       en
# 49  Central Business District  Melbourne        Melbourne   VIC       en
# 53                  Parkville  Melbourne        Parkville   VIC       en
# 54            North Melbourne  Melbourne  North Melbourne   VIC       en
# 55                  Parkville  Melbourne        Parkville   VIC       en
# 57             East Melbourne  Melbourne   East Melbourne   VIC       en
# 59             East Melbourne  Melbourne        Melbourne   VIC       en
# 64            North Melbourne  Melbourne  North Melbourne   VIC       en
# 65  Central Business District  Melbourne        Melbourne   VIC       en
# 75  Central Business District  Melbourne        Melbourne   VIC       en
# 76  Central Business District  Melbourne        Melbourne   VIC       en
# 79             East Melbourne  Melbourne   East Melbourne   VIC       en
# 82                  Southbank  Melbourne        Southbank   VIC       en
# 85             East Melbourne  Melbourne   East Melbourne   VIC       en
# 88  Central Business District  Melbourne        Melbourne   VIC       en
# 96  Central Business District  Melbourne        Melbourne   VIC       en
#
#     attractions_score  transport_score  total_score
# 6               0.161            0.322        0.483
# 10              0.206            0.279        0.443
# 24              0.126            0.126        0.252
# 30              0.187            0.375        0.562
# 44              0.145            0.276        0.393
# 49              0.110            0.326        0.436
# 53              0.266            0.266        0.532
# 54              0.000            0.294        0.294
# 55              0.213            0.239        0.434
# 57              0.059            0.216        0.275
# 59              0.000            0.311        0.311
# 64              0.143            0.201        0.344
# 65              0.184            0.492        0.676
# 75              0.189            0.288        0.456
# 76              0.166            0.280        0.422
# 79              0.053            0.246        0.299
# 82              0.216            0.375        0.591
# 85              0.444            0.907        1.351
# 88              0.000            0.345        0.345
# 96              0.000            0.294        0.294

# %% [markdown]
# ### Transport

# %%
Analyzer.lexicon.update(transport_map) # add to lexicon

# remember to remove previous dict from lexicon before procceding
def positive_score(text):
    positive_value = Analyzer.polarity_scores(text)['pos']
    return positive_value

# %%
all(map(Analyzer.lexicon.pop, transport_map)) # remove from lexicon
# Out:
# True

# %%
# %%time

df['transport_score'] = df['transit'].apply(positive_score)
df["total_score"] = df["attractions_score"] + df["transport_score"]
# Out:
# Wall time: 5.32 s

# %%
df = df.loc[df['city'] == "Melbourne"]
df.to_excel("transit_with_scores.xlsx")

# %%
df.head(20)
# Out:
#                                               transit  price  weekly_price  \
# 6   numerous buses on victoria parade will take yo...    100           NaN
# 10  yes, minutes to trains, trams and buses but mo...    228        1575.0
# 24  i have a myki available for you. it will have ...     64           NaN
# 30  trams at the door. hire a bike. book the airpo...    140           NaN
# 44  places to walk to .1min walk to lygon st .8min...    161        1030.0
# 49  flinders street station is a few minutes walk ...    220        1400.0
# 53  close and convenient public transport. easy ac...    190         900.0
# 54  tram stop almost at the door, and walking dist...    155         910.0
# 55  the apartment is perfectly located for you to ...     90           NaN
# 57  there is a tram to the city at end of street 1...     84           NaN
# 59  guests have access to three tram lines and the...    226        1575.0
# 64  you never need a car or worry about getting ar...    125         350.0
# 65  yes, trams are just at the end of the street, ...    125         800.0
# 75  trams, trains and buses are all within a block...     75         550.0
# 76  trams, trains and buses are all within a block...     75         550.0
# 79  public transport is very close and very conven...    109           NaN
# 82  parking i sure can be arranged at extra cost. ...    357        2400.0
# 85               exceptionally good. tram, bus, trams    109           NaN
# 88  there is a railway station and tram stop at th...    129         750.0
# 96  there is a tram stop in front of the apartment...    132         895.0
#
#     monthly_price          host_neighborhood                           street  \
# 6             NaN                        NaN   East Melbourne, VIC, Australia
# 10         5100.0  Central Business District        Melbourne, VIC, Australia
# 24            NaN  Central Business District        Melbourne, VIC, Australia
# 30            NaN  Central Business District        Melbourne, VIC, Australia
# 44         3400.0                   Richmond          Carlton, VIC, Australia
# 49         3862.0  Central Business District        Melbourne, VIC, Australia
# 53         2500.0                        NaN        Parkville, VIC, Australia
# 54         3300.0            North Melbourne  North Melbourne, VIC, Australia
# 55            NaN                  Parkville        Parkville, VIC, Australia
# 57            NaN             East Melbourne   East Melbourne, VIC, Australia
# 59            NaN             East Melbourne        Melbourne, VIC, Australia
# 64         1250.0            North Melbourne  North Melbourne, VIC, Australia
# 65         2700.0  Central Business District        Melbourne, VIC, Australia
# 75         1800.0  Central Business District        Melbourne, VIC, Australia
# 76         1900.0  Central Business District        Melbourne, VIC, Australia
# 79         3185.0             East Melbourne   East Melbourne, VIC, Australia
# 82         9000.0            South Melbourne        Southbank, VIC, Australia
# 85            NaN             East Melbourne   East Melbourne, VIC, Australia
# 88         2900.0  Central Business District        Melbourne, VIC, Australia
# 96         3763.0  Central Business District        Melbourne, VIC, Australia
#
#                  neighborhood       city           suburb state language  \
# 6                         NaN  Melbourne   East Melbourne   VIC       en
# 10  Central Business District  Melbourne        Melbourne   VIC       en
# 24  Central Business District  Melbourne        Melbourne   VIC       en
# 30  Central Business District  Melbourne        Melbourne   VIC       en
# 44                    Carlton  Melbourne          Carlton   VIC       en
# 49  Central Business District  Melbourne        Melbourne   VIC       en
# 53                  Parkville  Melbourne        Parkville   VIC       en
# 54            North Melbourne  Melbourne  North Melbourne   VIC       en
# 55                  Parkville  Melbourne        Parkville   VIC       en
# 57             East Melbourne  Melbourne   East Melbourne   VIC       en
# 59             East Melbourne  Melbourne        Melbourne   VIC       en
# 64            North Melbourne  Melbourne  North Melbourne   VIC       en
# 65  Central Business District  Melbourne        Melbourne   VIC       en
# 75  Central Business District  Melbourne        Melbourne   VIC       en
# 76  Central Business District  Melbourne        Melbourne   VIC       en
# 79             East Melbourne  Melbourne   East Melbourne   VIC       en
# 82                  Southbank  Melbourne        Southbank   VIC       en
# 85             East Melbourne  Melbourne   East Melbourne   VIC       en
# 88  Central Business District  Melbourne        Melbourne   VIC       en
# 96  Central Business District  Melbourne        Melbourne   VIC       en
#
#     attractions_score  transport_score  total_score
# 6               0.161            0.322        0.483
# 10              0.206            0.279        0.485
# 24              0.126            0.126        0.252
# 30              0.187            0.375        0.562
# 44              0.145            0.276        0.421
# 49              0.110            0.326        0.436
# 53              0.266            0.266        0.532
# 54              0.000            0.294        0.294
# 55              0.213            0.239        0.452
# 57              0.059            0.216        0.275
# 59              0.000            0.311        0.311
# 64              0.143            0.201        0.344
# 65              0.184            0.492        0.676
# 75              0.189            0.288        0.477
# 76              0.166            0.280        0.446
# 79              0.053            0.246        0.299
# 82              0.216            0.375        0.591
# 85              0.444            0.907        1.351
# 88              0.000            0.345        0.345
# 96              0.000            0.294        0.294
